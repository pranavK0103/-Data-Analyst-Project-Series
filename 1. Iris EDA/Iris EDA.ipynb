# %%
# We will do Exploratory Data Analysis (EDA) Using Python on Iris dataset

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#importing the iris dataset
iris=pd.read_csv("C:/Users/HP/Downloads/Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Summary Statistics

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
print("Dataset Information:")
iris.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
grouped_stats = iris.groupby('Species').describe()
print("\nGrouped Summary Statistics:")
print(grouped_stats)
# Out:
# Grouped Summary Statistics:
#                    Id                                                        \
#                 count   mean       std    min     25%    50%     75%    max
# Species
# Iris-setosa      50.0   25.5  14.57738    1.0   13.25   25.5   37.75   50.0
# Iris-versicolor  50.0   75.5  14.57738   51.0   63.25   75.5   87.75  100.0
# Iris-virginica   50.0  125.5  14.57738  101.0  113.25  125.5  137.75  150.0
#
#                 SepalLengthCm         ... PetalLengthCm      PetalWidthCm  \
#                         count   mean  ...           75%  max        count
# Species                               ...
# Iris-setosa              50.0  5.006  ...         1.575  1.9         50.0
# Iris-versicolor          50.0  5.936  ...         4.600  5.1         50.0
# Iris-virginica           50.0  6.588  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
grouped_stats.iloc[0:3,0:2]
# Out:
#                    Id
#                 count   mean
# Species
# Iris-setosa      50.0   25.5
# Iris-versicolor  50.0   75.5
# Iris-virginica   50.0  125.5

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.scatter(iris['SepalLengthCm'],iris['SepalWidthCm'],color='green',label='sepal')
plt.xlabel('Sepal_Length')
plt.ylabel('Sepal_width')
plt.title("Scatter plot SepalLen vs Sepalwid ")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(iris['PetalLengthCm'],iris['PetalWidthCm'],color='green',label='sepal')
plt.xlabel('Petal_Length')
plt.ylabel('Petal_width')
plt.title("Scatter plot PetalLen vs Petalwid ")
plt.legend()
plt.show()

# %%
setosa_sepal_length = iris[iris['Species'] == 'Iris-setosa ']['SepalLengthCm'].tolist()
versicolor_sepal_length = iris[iris['Species'] == 'Iris-versicolor']['SepalLengthCm'].tolist()
virginica_sepal_length = iris[iris['Species'] == 'Iris-virginica']['SepalLengthCm'].tolist()

# %%
 setosa_sepal_length
# Out:
# []

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
list(iris['Species'].value_counts())
# Out:
# [50, 50, 50]

# %%
import numpy as np
setosa_sepal_length = np.array(iris.loc[iris['Species'] == 'Iris-setosa', 'SepalLengthCm'])
versicolor_sepal_length = np.array(iris.loc[iris['Species'] == 'Iris-versicolor', 'SepalLengthCm'])
virginica_sepal_length = np.array(iris.loc[iris['Species'] == 'Iris-virginica', 'SepalLengthCm'])

# %%
setosa_sepal_length
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. ])

# %%
print("Unique Species Values:", iris['Species'].unique())
# Out:
# Unique Species Values: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print("\nFirst few rows of the dataset:")
print(iris.head())
# Out:
# First few rows of the dataset:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
## making the array for Sepal Length

# %%
setosa_sepal_length = iris.loc[iris['Species'] == 'Iris-setosa', 'SepalLengthCm'].tolist()
versicolor_sepal_length = iris.loc[iris['Species'] == 'Iris-versicolor', 'SepalLengthCm'].tolist()
virginica_sepal_length = iris.loc[iris['Species'] == 'Iris-virginica', 'SepalLengthCm'].tolist()

# %%
## creating the scatter plot for the sepal length with respect to their species

# %%
plt.scatter(range(len(setosa_sepal_length)), setosa_sepal_length, c='red', label='Setosa')
plt.scatter(range(len(versicolor_sepal_length)), versicolor_sepal_length, c='green', label='Versicolor')
plt.scatter(range(len(virginica_sepal_length)), virginica_sepal_length, c='blue', label='Virginica')

plt.xlabel('Index')
plt.ylabel('Sepal Length (cm)')
plt.title('Scatter Plot: Sepal Length for Each Species')
plt.legend()
plt.show()

# %%
## making the array for Sepal Width

# %%
setosa_sepal_width = iris.loc[iris['Species'] == 'Iris-setosa', 'SepalWidthCm'].tolist()
versicolor_sepal_width = iris.loc[iris['Species'] == 'Iris-versicolor', 'SepalWidthCm'].tolist()
virginca_sepal_width = iris.loc[iris['Species'] == 'Iris-virginica', 'SepalWidthCm'].tolist()

# %%
## creating the scatter plot for the sepal Width with respect to their species

# %%
plt.scatter(range(len(setosa_sepal_width)),setosa_sepal_width,c='red',label='setosa')
plt.scatter(range(len(versicolor_sepal_width)),versicolor_sepal_width,c='green',label='Versicolor')
plt.scatter(range(len(virginica_sepal_length)),virginica_sepal_length,c='blue',label='Virginica')
plt.xlabel('index')
plt.ylabel('Sepal_width')
plt.title("Scatter Plot: Sepal width for Each Species")
plt.legend()
plt.show()

# %%
## making the array for Petal Length

# %%
setosa_petal_length = iris.loc[iris['Species'] == 'Iris-setosa', 'PetalLengthCm'].tolist()
versicolor_petal_length = iris.loc[iris['Species'] == 'Iris-versicolor', 'PetalLengthCm'].tolist()
virginica_petal_length = iris.loc[iris['Species'] == 'Iris-virginica', 'PetalLengthCm'].tolist()

# %%
## creating the scatter plot for the Petal length with respect to their species

# %%
plt.scatter(range(len(setosa_petal_length)),setosa_petal_length,c='red',label='setosa')
plt.scatter(range(len(versicolor_petal_length)),versicolor_petal_length,c='green',label='Versicolor')
plt.scatter(range(len(virginica_petal_length)),virginica_petal_length,c='blue',label='Virginica')
plt.xlabel('Index')
plt.ylabel('Petal_width')
plt.title("Scatter Plot: Petal Legth for Each Species")
plt.legend()
plt.show()

# %%
## making the array for Petal Width

# %%
setosa_petal_width = iris.loc[iris['Species'] == 'Iris-setosa', 'PetalWidthCm'].tolist()
versicolor_petal_width = iris.loc[iris['Species'] == 'Iris-versicolor', 'PetalWidthCm'].tolist()
virginica_petal_width = iris.loc[iris['Species'] == 'Iris-virginica', 'PetalWidthCm'].tolist()

# %%
## creating the scatter plot for the Petal Width with respect to their species

# %%
plt.scatter(range(len(setosa_petal_width)),setosa_petal_width,c='red',label='setosa')
plt.scatter(range(len(versicolor_petal_width)),versicolor_petal_width,c='green',label='Versicolor')
plt.scatter(range(len(virginica_petal_width)),virginica_petal_width,c='blue',label='Virginica')
plt.xlabel('Index')
plt.ylabel('Petal_width')
plt.title("Scatter Plot: Petal width for Each Species")
plt.legend()
plt.show()

# %% [markdown]
# ------------

# %%
# Now for plotting the box plot we need to create the list of the numerical parameters and work accordingly

# %%
# SepalLength

# %%
SepalLength_data=list([setosa_sepal_length,versicolor_sepal_length,virginica_sepal_length])

# %%
plt.boxplot(SepalLength_data,labels=['Setosa', 'Versicolor', 'Virginica'] )
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Box Plot: Sepal Length for Each Species')
plt.show()

# %%
#SepalWidthCm

# %%
SepalWidth_data =list([setosa_sepal_width,versicolor_sepal_width,virginca_sepal_width])

# %%
plt.boxplot(SepalWidth_data,labels=['Setosa', 'Versicolor', 'Virginica'] )
plt.xlabel('Species')
plt.ylabel('SepalWidth(cm)')
plt.title('Box Plot: Sepal Width for Each Species')
plt.show()

# %%
#PetalLengthCm

# %%
PetalLength_data = list([setosa_petal_length,versicolor_petal_length,virginica_petal_length])

# %%
plt.boxplot(PetalLength_data,labels=['Setosa', 'Versicolor', 'Virginica'] )
plt.xlabel('Species')
plt.ylabel('SepalWidth(cm)')
plt.title('Box Plot: Petal Length for Each Species')
plt.show()

# %%
##PetalWidthCm

# %%
PetalWidth_data =list([setosa_petal_width,versicolor_petal_width,virginica_petal_width])

# %%
plt.boxplot(PetalWidth_data,labels=['Setosa', 'Versicolor', 'Virginica'] )
plt.xlabel('Species')
plt.ylabel('SepalWidth(cm)')
plt.title('Box Plot: Petal Width for Each Species')
plt.show()

# %%
##by different method
plt.boxplot([iris[iris['Species'] == 'Iris-setosa']['SepalLengthCm'],
             iris[iris['Species'] == 'Iris-versicolor']['SepalLengthCm'],
             iris[iris['Species'] == 'Iris-virginica']['SepalLengthCm']],
            labels=['Setosa', 'Versicolor', 'Virginica'])

plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Box Plot: Sepal Length for Each Species')
plt.show()

# %%
## plottng the histogram

# %%
## Sepal Length

# %%
plt.figure(figsize=(12, 8))
plt.hist(SepalLength_data,bins=20, color=['red', 'green', 'blue'], alpha=0.7, label=['Setosa', 'Versicolor', 'Virginica'])
plt.xlabel('Measurement (cm)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Sepal width

# %%
plt.figure(figsize=(12, 8))
plt.hist(SepalWidth_data,bins=20, color=['red', 'green', 'blue'], alpha=0.7, label=['Setosa', 'Versicolor', 'Virginica'])
plt.xlabel('Measurement (cm)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Petal Length
plt.figure(figsize=(12, 8))
plt.hist(PetalLength_data,bins=20, color=['red', 'green', 'blue'], alpha=0.7, label=['Setosa', 'Versicolor', 'Virginica'])
plt.xlabel('Measurement (cm)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Petal Width
plt.figure(figsize=(12, 8))
plt.hist(PetalWidth_data,bins=20, color=['red', 'green', 'blue'], alpha=0.7,label=['Setosa', 'Versicolor', 'Virginica'])
plt.xlabel('Measurement (cm)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = iris.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Calculate mean values for each numerical feature grouped by Species
mean_values = iris.groupby('Species').mean()

# %%
mean_values
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
plt.figure(figsize=(8,8))
plt.subplot(2, 2, 1)
plt.bar(list(mean_values["SepalLengthCm"].keys()),list(mean_values["SepalLengthCm"]))
plt.title('Mean Petal Width for Each Species')

plt.subplot(2, 2, 2)
plt.bar(list(mean_values["SepalWidthCm"].keys()),list(mean_values["SepalWidthCm"]))
plt.title('Mean Petal Width for Each Species')

plt.subplot(2, 2, 3)
plt.bar(list(mean_values["PetalLengthCm"].keys()),list(mean_values["PetalLengthCm"]))
plt.title('Mean Petal Width for Each Species')

plt.subplot(2, 2, 4)
plt.bar(list(mean_values["PetalWidthCm"].keys()),list(mean_values["PetalWidthCm"]))
plt.title('Mean Petal Width for Each Species')
plt.tight_layout()
plt.show()

# %%
# Calculate median values for each numerical feature grouped by Species
median_values = iris.groupby('Species').median()

# %%
median_values
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5            5.0           3.4           1.50
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %%
plt.figure(figsize=(8,8))
plt.subplot(2, 2, 1)
plt.bar(list(median_values["SepalLengthCm"].keys()),list(median_values["SepalLengthCm"]))
plt.title('Median Petal Width for Each Species')

plt.subplot(2, 2, 2)
plt.bar(list(median_values["SepalWidthCm"].keys()),list(median_values["SepalWidthCm"]))
plt.title('Median Petal Width for Each Species')

plt.subplot(2, 2, 3)
plt.bar(list(median_values["PetalLengthCm"].keys()),list(median_values["PetalLengthCm"]))
plt.title('Median Petal Width for Each Species')

plt.subplot(2, 2, 4)
plt.bar(list(median_values["PetalWidthCm"].keys()),list(median_values["PetalWidthCm"]))
plt.title('Median Petal Width for Each Species')
plt.tight_layout()
plt.show()

# %%
## kernal Plots

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Plot kernel density plots for each numerical feature grouped by Species
plt.figure(figsize=(12, 8))

# Sepal Length
plt.subplot(2, 2, 1)
sns.kdeplot(data=iris, x='SepalLengthCm', hue='Species', fill=True, common_norm=False)
plt.title('Kernel Density Plot: Sepal Length by Species')

# Sepal Width
plt.subplot(2, 2, 2)
sns.kdeplot(data=iris, x='SepalWidthCm', hue='Species', fill=True, common_norm=False)
plt.title('Kernel Density Plot: Sepal Width by Species')

# Petal Length
plt.subplot(2, 2, 3)
sns.kdeplot(data=iris, x='PetalLengthCm', hue='Species', fill=True, common_norm=False)
plt.title('Kernel Density Plot: Petal Length by Species')

# Petal Width
plt.subplot(2, 2, 4)
sns.kdeplot(data=iris, x='PetalWidthCm', hue='Species', fill=True, common_norm=False)
plt.title('Kernel Density Plot: Petal Width by Species')

plt.tight_layout()
plt.show()

# %%
#Stacked histogram

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Plot stacked histograms for each numerical feature grouped by Species
plt.figure(figsize=(12, 8))

# Sepal Length
plt.subplot(2, 2, 1)
sns.histplot(data=iris, x='SepalLengthCm', hue='Species', multiple='stack', kde=True)
plt.title('Stacked Histogram: Sepal Length by Species')

# Sepal Width
plt.subplot(2, 2, 2)
sns.histplot(data=iris, x='SepalWidthCm', hue='Species', multiple='stack', kde=True)
plt.title('Stacked Histogram: Sepal Width by Species')

# Petal Length
plt.subplot(2, 2, 3)
sns.histplot(data=iris, x='PetalLengthCm', hue='Species', multiple='stack', kde=True)
plt.title('Stacked Histogram: Petal Length by Species')

# Petal Width
plt.subplot(2, 2, 4)
sns.histplot(data=iris, x='PetalWidthCm', hue='Species', multiple='stack', kde=True)
plt.title('Stacked Histogram: Petal Width by Species')

plt.tight_layout()
plt.show()

# %%
## Swarm plot

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Plot swarm plots for each numerical feature grouped by Species
plt.figure(figsize=(12, 8))

# Sepal Length
plt.subplot(2, 2, 1)
sns.swarmplot(x='Species', y='SepalLengthCm', data=iris, palette='Set1')
plt.title('Swarm Plot: Sepal Length by Species')

# Sepal Width
plt.subplot(2, 2, 2)
sns.swarmplot(x='Species', y='SepalWidthCm', data=iris, palette='Set1')
plt.title('Swarm Plot: Sepal Width by Species')

# Petal Length
plt.subplot(2, 2, 3)
sns.swarmplot(x='Species', y='PetalLengthCm', data=iris, palette='Set1')
plt.title('Swarm Plot: Petal Length by Species')

# Petal Width
plt.subplot(2, 2, 4)
sns.swarmplot(x='Species', y='PetalWidthCm', data=iris, palette='Set1')
plt.title('Swarm Plot: Petal Width by Species')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
